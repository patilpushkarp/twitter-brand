# %% [markdown]
# # Scrapper for Starbucks

# %% [markdown]
# ## Scraping

# %%
# Import necessary packages
import traceback
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import datetime, timedelta
from multiprocessing import Pool
from functools import partial

from helpers import scrape

# %%
# Declare start date and end date (today's date)
start_date = datetime(2022,9,1)
today = datetime.today()

# %%
# Create a list of dates to be looped
dates = []
date = start_date
while today > date:
    dates.append(str(date).split(" ")[0])
    date += timedelta(days=1)

# %%
# Scrape data
with Pool(6) as p:
    p.map(partial(scrape, dates=dates), range(len(dates)-1))
# Out:
# Running query: 'starbucks since:2022-09-10 until:2022-09-11'
# Running query: 'starbucks since:2022-09-16 until:2022-09-17'
# Running query: 'starbucks since:2022-09-01 until:2022-09-02'
# Running query: 'starbucks since:2022-09-07 until:2022-09-08'
# Running query: 'starbucks since:2022-09-13 until:2022-09-14'
# Running query: 'starbucks since:2022-09-04 until:2022-09-05'
# Tweets scrapped: 9684
#
#
# Running query: 'starbucks since:2022-09-05 until:2022-09-06'
# Tweets scrapped: 10398
#
#
# Running query: 'starbucks since:2022-09-08 until:2022-09-09'
# Tweets scrapped: 11819
#
#
# Running query: 'starbucks since:2022-09-17 until:2022-09-18'
# Tweets scrapped: 12848
#
#
# Running query: 'starbucks since:2022-09-11 until:2022-09-12'
# Tweets scrapped: 15247
#
#
# Running query: 'starbucks since:2022-09-02 until:2022-09-03'
# Tweets scrapped: 17095
#
#
# Running query: 'starbucks since:2022-09-14 until:2022-09-15'
# Tweets scrapped: 10066
#
#
# Running query: 'starbucks since:2022-09-06 until:2022-09-07'
# Tweets scrapped: 10445
#
#
# Running query: 'starbucks since:2022-09-18 until:2022-09-19'
# Tweets scrapped: 10668
#
#
# Running query: 'starbucks since:2022-09-12 until:2022-09-13'
# Tweets scrapped: 9824
#
#
# Running query: 'starbucks since:2022-09-19 until:2022-09-20'
# Tweets scrapped: 10109
#
#
# Running query: 'starbucks since:2022-09-22 until:2022-09-23'
# Tweets scrapped: 18669
#
#
# Running query: 'starbucks since:2022-09-03 until:2022-09-04'
# Tweets scrapped: 15327
#
#
# Running query: 'starbucks since:2022-09-15 until:2022-09-16'
# Tweets scrapped: 19009
#
#
# Running query: 'starbucks since:2022-09-09 until:2022-09-10'
# Tweets scrapped: 10927
#
#
# Running query: 'starbucks since:2022-09-20 until:2022-09-21'
# Tweets scrapped: 17494
#
#
# Running query: 'starbucks since:2022-09-25 until:2022-09-26'
# Tweets scrapped: 11886
#
#
# Running query: 'starbucks since:2022-09-23 until:2022-09-24'
# Tweets scrapped: 12463
#
#
# Running query: 'starbucks since:2022-09-28 until:2022-09-29'
# Tweets scrapped: 12445
#
#
# Running query: 'starbucks since:2022-10-01 until:2022-10-02'
# Tweets scrapped: 13544
#
#
# Running query: 'starbucks since:2022-10-04 until:2022-10-05'
# Tweets scrapped: 9551
#
#
# Running query: 'starbucks since:2022-09-26 until:2022-09-27'
# Tweets scrapped: 11505
#
#
# Running query: 'starbucks since:2022-09-21 until:2022-09-22'
# Tweets scrapped: 11349
#
#
# Running query: 'starbucks since:2022-09-24 until:2022-09-25'
# Tweets scrapped: 10727
#
#
# Running query: 'starbucks since:2022-10-02 until:2022-10-03'
# Tweets scrapped: 12739
#
#
# Running query: 'starbucks since:2022-09-29 until:2022-09-30'
# Tweets scrapped: 11749
#
#
# Running query: 'starbucks since:2022-10-05 until:2022-10-06'
# Tweets scrapped: 10189
#
#
# Running query: 'starbucks since:2022-09-27 until:2022-09-28'
# Tweets scrapped: 11643
#
#
# Running query: 'starbucks since:2022-10-07 until:2022-10-08'
# Tweets scrapped: 9990
#
#
# Running query: 'starbucks since:2022-10-10 until:2022-10-11'
# Tweets scrapped: 11223
#
#
# Running query: 'starbucks since:2022-10-03 until:2022-10-04'
# Tweets scrapped: 12340
#
#
# Running query: 'starbucks since:2022-09-30 until:2022-10-01'
# Tweets scrapped: 10503
#
#
# Running query: 'starbucks since:2022-10-13 until:2022-10-14'
# Tweets scrapped: 8607
#
#
# Running query: 'starbucks since:2022-10-11 until:2022-10-12'
# Tweets scrapped: 13045
#
#
# Running query: 'starbucks since:2022-10-06 until:2022-10-07'
# Tweets scrapped: 12918
#
#
# Running query: 'starbucks since:2022-10-08 until:2022-10-09'
# Tweets scrapped: 12470
#
#
# Running query: 'starbucks since:2022-10-16 until:2022-10-17'
# Tweets scrapped: 10999
#
#
# Running query: 'starbucks since:2022-10-14 until:2022-10-15'
# Tweets scrapped: 9522
#
#
# Running query: 'starbucks since:2022-10-12 until:2022-10-13'
# Tweets scrapped: 13654
#
#
# Running query: 'starbucks since:2022-10-19 until:2022-10-20'
# Tweets scrapped: 9152
#
#
# Running query: 'starbucks since:2022-10-09 until:2022-10-10'
# Tweets scrapped: 12615
#
#
# Running query: 'starbucks since:2022-10-22 until:2022-10-23'
# Tweets scrapped: 8612
#
#
# Running query: 'starbucks since:2022-10-17 until:2022-10-18'
# Tweets scrapped: 9925
#
#
# Running query: 'starbucks since:2022-10-15 until:2022-10-16'
# Tweets scrapped: 8486
#
#
# Running query: 'starbucks since:2022-10-25 until:2022-10-26'
# Tweets scrapped: 12427
#
#
# Running query: 'starbucks since:2022-10-28 until:2022-10-29'
# Tweets scrapped: 8590
#
#
# Running query: 'starbucks since:2022-10-23 until:2022-10-24'
# Tweets scrapped: 12336
#
#
# Running query: 'starbucks since:2022-10-20 until:2022-10-21'
# Tweets scrapped: 8415
#
#
# Running query: 'starbucks since:2022-10-31 until:2022-11-01'
# Tweets scrapped: 9859
#
#
# Running query: 'starbucks since:2022-10-18 until:2022-10-19'
# Tweets scrapped: 8379
#
#
# Running query: 'starbucks since:2022-10-29 until:2022-10-30'
# Tweets scrapped: 7870
#
#
# Running query: 'starbucks since:2022-10-24 until:2022-10-25'
# Tweets scrapped: 10593
#
#
# Running query: 'starbucks since:2022-10-26 until:2022-10-27'
# Tweets scrapped: 10694
#
#
# Running query: 'starbucks since:2022-10-21 until:2022-10-22'
# Tweets scrapped: 8991
#
#
# Running query: 'starbucks since:2022-11-01 until:2022-11-02'
# Tweets scrapped: 11395
#
#
# Running query: 'starbucks since:2022-11-03 until:2022-11-04'
# Tweets scrapped: 7454
#
#
# Running query: 'starbucks since:2022-10-30 until:2022-10-31'
# Tweets scrapped: 9331
#
#
# Tweets scrapped: 11314
#
#
# Running query: 'starbucks since:2022-10-27 until:2022-10-28'
# Tweets scrapped: 10259
#
#
# Tweets scrapped: 10096
#
#
# Running query: 'starbucks since:2022-11-02 until:2022-11-03'
# Tweets scrapped: 8214
#
#
# Tweets scrapped: 10358
#
#
# Tweets scrapped: 22728
#
#
# Running query: 'starbucks since:2022-11-04 until:2022-11-05'
# Tweets scrapped: 20703
#
#
# Tweets scrapped: 15421
#
#
# Running query: 'starbucks since:2022-11-05 until:2022-11-06'
# Tweets scrapped: 10510

# %% [markdown]
# ## Combining Scrapped Data

# %%
import pandas as pd
import os
import glob

# %%
# Get all the csv files in the folder
path = './../data/starbucks/'
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
# Combine the data by iteratively loading files
files = []
for f in csv_files:
    files.append(pd.read_csv(f, engine='python'))

final = pd.concat(files, axis=0, ignore_index=True)

# %%
final.to_hdf('./../data/starbucks/data.h5', key='starbucks')
# Out:
# /var/folders/zl/bqtzmz3s0xl5_ddgbjsqxsww0000gn/T/ipykernel_35888/1589411627.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block1_values] [items->Index(['Unnamed: 0', 'tweet', 'conversation_id', 'date', 'hashtags',
#        'inReplyToTweetId', 'reply_to', 'language', 'likes_count', 'media',
#        'mentions', 'quoted_tweet', 'retweets_count', 'link',
#        'user_status_count', 'location', 'name', 'description', 'verified',
#        'url', 'user_id', 'username'],
#       dtype='object')]
#
#   final.to_hdf('./../data/starbucks/data.h5', key='starbucks')

# %%
final.shape
# Out:
# (769439, 28)

# %% [markdown]
# ## Supporting functions
#
# ```python
# import traceback
# import pandas as pd
# from datetime import datetime, timedelta
# import snscrape.modules.twitter as sntwitter
#
#
# def scrape(x, dates):
#     try:
#         tweets_list= []
#         query = f"starbucks since:{dates[x]} until:{dates[x+1]}"
#         print(f"Running query: '{query}'")
#         for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
#             td = get_schema(tweet)
#             tweets_list.append(td)
#         n_tweets = len(tweets_list)
#         print(f"Tweets scrapped: {n_tweets}")
#         df = pd.DataFrame(tweets_list)
#         df.to_csv(f'./../data/starbucks/{dates[x]}.csv')
#         print("\n")
#     except:
#         traceback.print_exc()
#
#
# def get_schema(tweet):
#     return {
#         'tweet': tweet.content,
#         'conversation_id': tweet.conversationId,
#         'date':tweet.date,
#         'hashtags':tweet.hashtags,
#         'id':tweet.id,
#         'inReplyToTweetId':tweet.inReplyToTweetId,
#         'reply_to':tweet.inReplyToUser,
#         'language':tweet.lang,
#         'likes_count':tweet.likeCount,
#         'media':tweet.media,
#         'mentions':tweet.mentionedUsers,
#         'quote_count':tweet.quoteCount,
#         'quoted_tweet':tweet.quotedTweet,
#         'replies_count':tweet.replyCount,
#         'retweets_count':tweet.retweetCount,
#         'link':tweet.url,
#         'followers_count':tweet.user.followersCount,
#         'following_count':tweet.user.friendsCount,
#         'favourites_count':tweet.user.favouritesCount,
#         'user_status_count':tweet.user.statusesCount,
#         'location':tweet.user.location,
#         'name':tweet.user.displayname,
#         'description':tweet.user.description,
#         'verified':tweet.user.verified,
#         'url':tweet.user.linkUrl,
#         'user_id':tweet.user.id,
#         'username':tweet.user.username}
# ```
